# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Amber'

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.bash_history',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.copilot',
#  '.git',
#  '.gitconfig',
#  '.gradle',
#  '.h2.server.properties',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jdks',
#  '.jupyter',
#  '.lesshst',
#  '.m2',
#  '.node_repl_history',
#  '.quokka',
#  '.redhat',
#  '.SmartTomcat',
#  '.TurboVPN',
#  '.viminfo',
#  '.vs-kubernetes',
#  '.vscode',
#  '.vscode-shared',
#  '.wallaby',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'churn_analysis.ipynb',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'git',
#  'IdeaProjects',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'miktex-console.lock',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{3e91efec-9938-11f0-9c5b-dc6fc1887cde}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{3e91efec-9938-11f0-9c5b-dc6fc1887cde}.TxR.1.regtrans-ms',
# ...

# %%
import os

os.path.exists(r"C:\Users\Amber\OneDrive - gla.ac.in\Desktop\Supply-Chain-Performance-Analytics")
# Out:
# True

# %%
import os
os.getcwd()

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Amber\\OneDrive - gla.ac.in\\Desktop\\Supply-Chain-Performance-Analytics\\Notebooks'

# %%
import os

os.chdir(r"C:\Users\Amber\OneDrive - gla.ac.in\Desktop\Supply-Chain-Performance-Analytics\Notebooks")

os.getcwd()
# Out:
# 'C:\\Users\\Amber\\OneDrive - gla.ac.in\\Desktop\\Supply-Chain-Performance-Analytics\\Notebooks'

# %%
import pandas as pd

df = pd.read_csv("../Dataset/Cleaned/supply_chain_cleaned.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2
#       3 df = pd.read_csv("../Dataset/Cleaned/supply_chain_cleaned.csv")
#       4
#
# ModuleNotFoundError: No module named 'pandas'
